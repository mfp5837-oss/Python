# %%
import spacy
nlp = spacy.cli.download("en_core_web_lg")
nlp = spacy.load("en_core_web_lg")
filepath = "8x2.txt"
f = open(filepath, 'r', encoding='utf8').read()
spacyRead = nlp(f)
for token in spacyRead:
    print(token.text, "---->", token.pos_, ":::::", token.lemma_)
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# Introduction ----> PROPN ::::: Introduction
#
#  ----> SPACE :::::
#
# Buster ----> PROPN ::::: Buster
# , ----> PUNCT ::::: ,
# his ----> PRON ::::: his
# mom ----> NOUN ::::: mom
# and ----> CCONJ ::::: and
# Harry ----> PROPN ::::: Harry
# Mills ----> PROPN ::::: Mills
# are ----> AUX ::::: be
# walking ----> VERB ::::: walk
# past ----> ADP ::::: past
# the ----> DET ::::: the
# Sugar ----> PROPN ::::: Sugar
# Bowl ----> PROPN ::::: Bowl
# . ----> PUNCT ::::: .
# Buster ----> PROPN ::::: Buster
# is ----> AUX ::::: be
# holding ----> VERB ::::: hold
# a ----> DET ::::: a
# balloon ----> NOUN ::::: balloon
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# Wow ----> INTJ ::::: wow
# ! ----> PUNCT ::::: !
# What ----> PRON ::::: what
# a ----> DET ::::: a
# great ----> ADJ ::::: great
# circus ----> NOUN ::::: circus
# ! ----> PUNCT ::::: !
# How ----> SCONJ ::::: how
# do ----> AUX ::::: do
# they ----> PRON ::::: they
# get ----> VERB ::::: get
# poodles ----> NOUN ::::: poodle
# to ----> PART ::::: to
# dance ----> VERB ::::: dance
# like ----> ADP ::::: like
# that ----> PRON ::::: that
# ? ----> PUNCT ::::: ?
# And ----> CCONJ ::::: and
# that ----> DET ::::: that
# clown ----> NOUN ::::: clown
# on ----> ADP ::::: on
# stilts ----> NOUN ::::: stilt
# the ----> DET ::::: the
# whole ----> ADJ ::::: whole
# time ----> NOUN ::::: time
# . ----> PUNCT ::::: .
# How ----> SCONJ ::::: how
# ’d ----> NOUN ::::: ’d
# he ----> PRON ::::: he
# do ----> VERB ::::: do
# it ----> PRON ::::: it
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# Bitzi ----> PROPN ::::: Bitzi
# : ----> PUNCT ::::: :
# Ahem ----> PROPN ::::: Ahem
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Harry ----> PROPN ::::: Harry
# checks ----> VERB ::::: check
# his ----> PRON ::::: his
# watch ----> NOUN ::::: watch
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Harry ----> PROPN ::::: Harry
# Mills ----> PROPN ::::: Mills
# : ----> PUNCT ::::: :
# Well ----> INTJ ::::: well
# I ----> PRON ::::: I
# should ----> AUX ::::: should
# probably ----> ADV ::::: probably
# be ----> AUX ::::: be
# heading ----> VERB ::::: head
# home ----> ADV ::::: home
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# Why ----> SCONJ ::::: why
# ? ----> PUNCT ::::: ?
# It ----> PRON ::::: it
# 's ----> AUX ::::: be
# only ----> ADV ::::: only
# three ----> NUM ::::: three
# - ----> PUNCT ::::: -
# o ----> NOUN ::::: o
# - ----> NOUN ::::: -
# clock ----> NOUN ::::: clock
# . ----> PUNCT ::::: .
# Hey ----> INTJ ::::: hey
# , ----> PUNCT ::::: ,
# is ----> AUX ::::: be
# anybody ----> PRON ::::: anybody
# hungry ----> ADJ ::::: hungry
# ? ----> PUNCT ::::: ?
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# starving ----> VERB ::::: starve
# ! ----> PUNCT ::::: !
# I ----> PRON ::::: I
# bet ----> VERB ::::: bet
# you ----> PRON ::::: you
# know ----> VERB ::::: know
# what ----> PRON ::::: what
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# gon ----> VERB ::::: go
# na ----> PART ::::: to
# have ----> VERB ::::: have
# , ----> PUNCT ::::: ,
# Harry ----> PROPN ::::: Harry
# ! ----> PUNCT ::::: !
# Come ----> VERB ::::: come
# on ----> ADP ::::: on
# ! ----> PUNCT ::::: !
#
#
#  ----> SPACE :::::
#
#
# He ----> PRON ::::: he
# runs ----> VERB ::::: run
# into ----> ADP ::::: into
# the ----> DET ::::: the
# Sugar ----> PROPN ::::: Sugar
# Bowl ----> PROPN ::::: Bowl
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Harry ----> PROPN ::::: Harry
# Mills ----> PROPN ::::: Mills
# : ----> PUNCT ::::: :
# Maybe ----> ADV ::::: maybe
# we ----> PRON ::::: we
# both ----> PRON ::::: both
# should ----> AUX ::::: should
# tell ----> VERB ::::: tell
# him ----> PRON ::::: he
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# He ----> PRON ::::: he
# and ----> CCONJ ::::: and
# Bitzi ----> PROPN ::::: Bitzi
# enter ----> VERB ::::: enter
# the ----> DET ::::: the
# Sugar ----> PROPN ::::: Sugar
# Bowl ----> PROPN ::::: Bowl
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# looks ----> VERB ::::: look
# at ----> ADP ::::: at
# the ----> DET ::::: the
# menu ----> NOUN ::::: menu
# on ----> ADP ::::: on
# the ----> DET ::::: the
# Sugar ----> PROPN ::::: Sugar
# Bowl ----> PROPN ::::: Bowl
# ’s ----> PART ::::: ’s
# wall ----> NOUN ::::: wall
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# There ----> ADV ::::: there
# it ----> PRON ::::: it
# is ----> AUX ::::: be
# ! ----> PUNCT ::::: !
# The ----> DET ::::: the
# Harry ----> PROPN ::::: Harry
# Mills ----> PROPN ::::: Mills
# Meatball ----> PROPN ::::: Meatball
# Experience ----> PROPN ::::: Experience
# ! ----> PUNCT ::::: !
# Three ----> NUM ::::: three
# meatballs ----> NOUN ::::: meatball
# and ----> CCONJ ::::: and
# four ----> NUM ::::: four
# strips ----> NOUN ::::: strip
# of ----> ADP ::::: of
# bacon ----> NOUN ::::: bacon
# smothered ----> VERB ::::: smother
# in ----> ADP ::::: in
# marinara ----> NOUN ::::: marinara
# sauce ----> NOUN ::::: sauce
# and ----> CCONJ ::::: and
# melted ----> VERB ::::: melt
# provolone ----> NOUN ::::: provolone
# ! ----> PUNCT ::::: !
# How ----> SCONJ ::::: how
# 'd ----> AUX ::::: would
# you ----> PRON ::::: you
# get ----> VERB ::::: get
# a ----> DET ::::: a
# sandwich ----> NOUN ::::: sandwich
# named ----> VERB ::::: name
# after ----> ADP ::::: after
# you ----> PRON ::::: you
# , ----> PUNCT ::::: ,
# Harry ----> PROPN ::::: Harry
# ? ----> PROPN ::::: ?
#
#
#  ----> SPACE :::::
#
#
# Harry ----> PROPN ::::: Harry
# Mills ----> PROPN ::::: Mills
# : ----> PUNCT ::::: :
# By ----> ADP ::::: by
# living ----> VERB ::::: live
# alone ----> ADV ::::: alone
# and ----> CCONJ ::::: and
# not ----> PART ::::: not
# knowing ----> VERB ::::: know
# how ----> SCONJ ::::: how
# to ----> PART ::::: to
# cook ----> VERB ::::: cook
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# suppose ----> VERB ::::: suppose
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# They ----> PRON ::::: they
# sit ----> VERB ::::: sit
# down ----> ADP ::::: down
# at ----> ADP ::::: at
# a ----> DET ::::: a
# table ----> NOUN ::::: table
# . ----> PUNCT ::::: .
# Buster ----> PROPN ::::: Buster
# looks ----> VERB ::::: look
# at ----> ADP ::::: at
# a ----> DET ::::: a
# newspaper ----> NOUN ::::: newspaper
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# ( ----> PUNCT ::::: (
# whistles ----> NOUN ::::: whistle
# ) ----> PUNCT ::::: )
#
#
#  ----> SPACE :::::
#
#
# Mrs. ----> PROPN ::::: Mrs.
# Baxter ----> PROPN ::::: Baxter
# : ----> PUNCT ::::: :
# Buster ----> PROPN ::::: Buster
# , ----> PUNCT ::::: ,
# honey ----> NOUN ::::: honey
# , ----> PUNCT ::::: ,
# there ----> PRON ::::: there
# 's ----> VERB ::::: be
# something ----> PRON ::::: something
# Harry ----> PROPN ::::: Harry
# and ----> CCONJ ::::: and
# I ----> PRON ::::: I
# would ----> AUX ::::: would
# like ----> VERB ::::: like
# to ----> PART ::::: to
# talk ----> VERB ::::: talk
# to ----> ADP ::::: to
# you ----> PRON ::::: you
# about ----> ADP ::::: about
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# Hey ----> INTJ ::::: hey
# look ----> VERB ::::: look
# ! ----> PUNCT ::::: !
# House ----> PROPN ::::: House
# Wars ----> PROPN ::::: Wars
# is ----> AUX ::::: be
# playing ----> VERB ::::: play
# ! ----> PUNCT ::::: !
# You ----> PRON ::::: you
# know ----> VERB ::::: know
# , ----> PUNCT ::::: ,
# it ----> PRON ::::: it
# 's ----> AUX ::::: be
# that ----> DET ::::: that
# new ----> ADJ ::::: new
# animated ----> ADJ ::::: animated
# movie ----> NOUN ::::: movie
# where ----> SCONJ ::::: where
# the ----> DET ::::: the
# kitchen ----> NOUN ::::: kitchen
# things ----> NOUN ::::: thing
# battle ----> VERB ::::: battle
# the ----> DET ::::: the
# cleaning ----> VERB ::::: clean
# things ----> NOUN ::::: thing
# ? ----> PUNCT ::::: ?
# And ----> CCONJ ::::: and
# it ----> PRON ::::: it
# 's ----> AUX ::::: be
# starting ----> VERB ::::: start
# in ----> ADP ::::: in
# fifteen ----> NUM ::::: fifteen
# minutes ----> NOUN ::::: minute
# ! ----> PUNCT ::::: !
# He ----> PRON ::::: he
# runs ----> VERB ::::: run
# to ----> ADP ::::: to
# the ----> DET ::::: the
# door ----> NOUN ::::: door
# . ----> PUNCT ::::: .
# Come ----> VERB ::::: come
# on ----> ADP ::::: on
# ! ----> PUNCT ::::: !
# We ----> PRON ::::: we
# 'll ----> AUX ::::: will
# eat ----> VERB ::::: eat
# later ----> ADV ::::: later
# ! ----> PUNCT ::::: !
# If ----> SCONJ ::::: if
# we ----> PRON ::::: we
# hurry ----> VERB ::::: hurry
# , ----> PUNCT ::::: ,
# we ----> PRON ::::: we
# can ----> AUX ::::: can
# just ----> ADV ::::: just
# make ----> VERB ::::: make
# it ----> PRON ::::: it
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# He ----> PRON ::::: he
# runs ----> VERB ::::: run
# out ----> ADP ::::: out
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Harry ----> PROPN ::::: Harry
# Mills ----> PROPN ::::: Mills
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# tried ----> VERB ::::: try
# .. ----> PUNCT ::::: ..
#
#
#  ----> SPACE :::::
#
#
# Mrs. ----> PROPN ::::: Mrs.
# Baxter ----> PROPN ::::: Baxter
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# guess ----> VERB ::::: guess
# I ----> PRON ::::: I
# 'll ----> AUX ::::: will
# just ----> ADV ::::: just
# tell ----> VERB ::::: tell
# him ----> PRON ::::: he
# tonight ----> NOUN ::::: tonight
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# is ----> AUX ::::: be
# outside ----> ADV ::::: outside
# knocking ----> VERB ::::: knock
# at ----> ADP ::::: at
# the ----> DET ::::: the
# window ----> NOUN ::::: window
# and ----> CCONJ ::::: and
# pointing ----> VERB ::::: point
# at ----> ADP ::::: at
# his ----> PRON ::::: his
# watch ----> NOUN ::::: watch
# . ----> PUNCT ::::: .
# The ----> DET ::::: the
# grown ----> ADJ ::::: grown
# - ----> PUNCT ::::: -
# ups ----> NOUN ::::: up
# stand ----> VERB ::::: stand
# up ----> ADP ::::: up
# . ----> PUNCT ::::: .
# Buster ----> PROPN ::::: Buster
# suddenly ----> ADV ::::: suddenly
# looks ----> VERB ::::: look
# sad ----> ADJ ::::: sad
# and ----> CCONJ ::::: and
# lets ----> VERB ::::: let
# the ----> DET ::::: the
# balloon ----> NOUN ::::: balloon
# go ----> VERB ::::: go
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Title ----> PROPN ::::: Title
# Card ----> NOUN ::::: card
# : ----> PUNCT ::::: :
# Magnifying ----> PROPN ::::: Magnifying
# Glass ----> PROPN ::::: Glass
#
#  ----> SPACE :::::
#
# That ----> DET ::::: that
# evening ----> NOUN ::::: evening
# , ----> PUNCT ::::: ,
# Buster ----> PROPN ::::: Buster
# lies ----> VERB ::::: lie
# in ----> ADP ::::: in
# bed ----> NOUN ::::: bed
# . ----> PUNCT ::::: .
# He ----> PRON ::::: he
# plays ----> VERB ::::: play
# with ----> ADP ::::: with
# a ----> DET ::::: a
# baseball ----> NOUN ::::: baseball
# signed ----> VERB ::::: sign
# “ ----> PUNCT ::::: "
# Ebos ----> PROPN ::::: Ebos
# ” ----> PUNCT ::::: "
# and ----> CCONJ ::::: and
# glove ----> NOUN ::::: glove
# and ----> CCONJ ::::: and
# looks ----> VERB ::::: look
# scared ----> ADJ ::::: scared
# . ----> PUNCT ::::: .
# There ----> PRON ::::: there
# is ----> VERB ::::: be
# a ----> DET ::::: a
# knock ----> NOUN ::::: knock
# on ----> ADP ::::: on
# the ----> DET ::::: the
# door ----> NOUN ::::: door
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Mrs. ----> PROPN ::::: Mrs.
# Baxter ----> PROPN ::::: Baxter
# : ----> PUNCT ::::: :
# Buster ----> PROPN ::::: Buster
# , ----> PUNCT ::::: ,
# are ----> AUX ::::: be
# you ----> PRON ::::: you
# still ----> ADV ::::: still
# up ----> ADV ::::: up
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# quickly ----> ADV ::::: quickly
# pretends ----> VERB ::::: pretend
# to ----> PART ::::: to
# be ----> AUX ::::: be
# asleep ----> ADJ ::::: asleep
# . ----> PUNCT ::::: .
# Bitzi ----> NOUN ::::: bitzi
# comes ----> VERB ::::: come
# in ----> ADV ::::: in
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# Mmm ----> PROPN ::::: Mmm
# . ----> PUNCT ::::: .
# Comet ----> PROPN ::::: Comet
# is ----> AUX ::::: be
# coming ----> VERB ::::: come
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Bitzi ----> PROPN ::::: Bitzi
# puts ----> VERB ::::: put
# the ----> DET ::::: the
# glove ----> NOUN ::::: glove
# away ----> ADV ::::: away
# and ----> CCONJ ::::: and
# adjusts ----> VERB ::::: adjust
# Buster ----> PROPN ::::: Buster
# ’s ----> PART ::::: ’s
# blanket ----> NOUN ::::: blanket
# . ----> PUNCT ::::: .
# Buster ----> PROPN ::::: Buster
# smiles ----> VERB ::::: smile
# and ----> CCONJ ::::: and
# she ----> PRON ::::: she
# leaves ----> VERB ::::: leave
# the ----> DET ::::: the
# room ----> NOUN ::::: room
# . ----> PUNCT ::::: .
# As ----> ADV ::::: as
# soon ----> ADV ::::: soon
# as ----> SCONJ ::::: as
# she ----> PRON ::::: she
# is ----> AUX ::::: be
# outside ----> ADV ::::: outside
# , ----> PUNCT ::::: ,
# he ----> PRON ::::: he
# plays ----> VERB ::::: play
# with ----> ADP ::::: with
# the ----> DET ::::: the
# ball ----> NOUN ::::: ball
# again ----> ADV ::::: again
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# ( ----> PUNCT ::::: (
# sad ----> ADJ ::::: sad
# sigh ----> NOUN ::::: sigh
# ) ----> PUNCT ::::: )
#
#
#  ----> SPACE :::::
#
#
# * ----> PUNCT ::::: *
# * ----> PUNCT ::::: *
# * ----> PUNCT ::::: *
#
#
#  ----> SPACE :::::
#
#
# The ----> DET ::::: the
# next ----> ADJ ::::: next
# morning ----> NOUN ::::: morning
# , ----> PUNCT ::::: ,
# Buster ----> PROPN ::::: Buster
# looks ----> VERB ::::: look
# into ----> ADP ::::: into
# the ----> DET ::::: the
# kitchen ----> NOUN ::::: kitchen
# with ----> ADP ::::: with
# his ----> PRON ::::: his
# school ----> NOUN ::::: school
# bag ----> NOUN ::::: bag
# on ----> ADP ::::: on
# his ----> PRON ::::: his
# back ----> NOUN ::::: back
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# Morning ----> NOUN ::::: morning
# , ----> PUNCT ::::: ,
# mom ----> NOUN ::::: mom
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
# think ----> VERB ::::: think
# I ----> PRON ::::: I
# 'll ----> AUX ::::: will
# go ----> VERB ::::: go
# right ----> ADV ::::: right
# to ----> ADP ::::: to
# school ----> NOUN ::::: school
# . ----> PUNCT ::::: .
# See ----> VERB ::::: see
# you ----> PRON ::::: you
# ! ----> PUNCT ::::: !
# Have ----> VERB ::::: have
# a ----> DET ::::: a
# great ----> ADJ ::::: great
# day ----> NOUN ::::: day
# ! ----> PUNCT ::::: !
#
#
#  ----> SPACE :::::
#
#
# He ----> PRON ::::: he
# rushes ----> VERB ::::: rush
# out ----> ADP ::::: out
# , ----> PUNCT ::::: ,
# but ----> CCONJ ::::: but
# Bitzi ----> NOUN ::::: bitzi
# runs ----> NOUN ::::: run
# after ----> ADP ::::: after
# him ----> PRON ::::: he
# in ----> ADP ::::: in
# her ----> PRON ::::: her
# dressing ----> NOUN ::::: dressing
# gown ----> NOUN ::::: gown
# and ----> CCONJ ::::: and
# holds ----> VERB ::::: hold
# him ----> PRON ::::: he
# back ----> ADV ::::: back
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Mrs. ----> PROPN ::::: Mrs.
# Baxter ----> PROPN ::::: Baxter
# : ----> PUNCT ::::: :
# Hold ----> VERB ::::: hold
# on ----> ADP ::::: on
# , ----> PUNCT ::::: ,
# Buster ----> PROPN ::::: Buster
# ! ----> PUNCT ::::: !
# It ----> PRON ::::: it
# 's ----> AUX ::::: be
# only ----> ADV ::::: only
# 7:30 ----> NUM ::::: 7:30
# . ----> PUNCT ::::: .
# Sit ----> VERB ::::: sit
# down ----> ADP ::::: down
# and ----> CCONJ ::::: and
# have ----> VERB ::::: have
# some ----> DET ::::: some
# breakfast ----> NOUN ::::: breakfast
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# Umm ----> PROPN ::::: Umm
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# not ----> PART ::::: not
# hungry ----> ADJ ::::: hungry
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Mrs. ----> PROPN ::::: Mrs.
# Baxter ----> PROPN ::::: Baxter
# : ----> PUNCT ::::: :
# Buster ----> PROPN ::::: Buster
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# 're ----> AUX ::::: be
# always ----> ADV ::::: always
# hungry ----> ADJ ::::: hungry
# . ----> PUNCT ::::: .
# Besides ----> ADV ::::: besides
# , ----> PUNCT ::::: ,
# there ----> PRON ::::: there
# 's ----> VERB ::::: be
# something ----> PRON ::::: something
# I ----> PRON ::::: I
# have ----> VERB ::::: have
# to ----> PART ::::: to
# tell ----> VERB ::::: tell
# you ----> PRON ::::: you
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# They ----> PRON ::::: they
# go ----> VERB ::::: go
# into ----> ADP ::::: into
# the ----> DET ::::: the
# kitchen ----> NOUN ::::: kitchen
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# Do ----> AUX ::::: do
# n't ----> PART ::::: not
# bother ----> VERB ::::: bother
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
# already ----> ADV ::::: already
# know ----> VERB ::::: know
# what ----> PRON ::::: what
# you ----> PRON ::::: you
# 're ----> AUX ::::: be
# gon ----> VERB ::::: go
# na ----> PART ::::: to
# say ----> VERB ::::: say
# . ----> PUNCT ::::: .
# Harry ----> PROPN ::::: Harry
# 's ----> AUX ::::: 's
# going ----> VERB ::::: go
# away ----> ADV ::::: away
# and ----> CCONJ ::::: and
# he ----> PRON ::::: he
# 's ----> AUX ::::: be
# not ----> PART ::::: not
# coming ----> VERB ::::: come
# back ----> ADV ::::: back
# because ----> SCONJ ::::: because
# he ----> PRON ::::: he
# 's ----> AUX ::::: be
# decided ----> VERB ::::: decide
# to ----> PART ::::: to
# become ----> VERB ::::: become
# a ----> DET ::::: a
# pilot ----> NOUN ::::: pilot
# or ----> CCONJ ::::: or
# a ----> DET ::::: a
# sponge ----> NOUN ::::: sponge
# diver ----> NOUN ::::: diver
# or ----> CCONJ ::::: or
# some ----> DET ::::: some
# other ----> ADJ ::::: other
# job ----> NOUN ::::: job
# you ----> PRON ::::: you
# ca ----> AUX ::::: can
# n't ----> PART ::::: not
# do ----> VERB ::::: do
# in ----> ADP ::::: in
# Elwood ----> PROPN ::::: Elwood
# City ----> PROPN ::::: City
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Mrs. ----> PROPN ::::: Mrs.
# Baxter ----> PROPN ::::: Baxter
# : ----> PUNCT ::::: :
# No ----> DET ::::: no
# sweety ----> NOUN ::::: sweety
# , ----> PUNCT ::::: ,
# Harry ----> PROPN ::::: Harry
# is ----> AUX ::::: be
# n't ----> PART ::::: not
# going ----> VERB ::::: go
# anywhere ----> ADV ::::: anywhere
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# He ----> PRON ::::: he
# is ----> AUX ::::: be
# n't ----> PART ::::: not
# ? ----> PUNCT ::::: ?
# That ----> PRON ::::: that
# 's ----> AUX ::::: be
# great ----> ADJ ::::: great
# ! ----> PUNCT ::::: !
# Hahahaha ----> INTJ ::::: hahahaha
# , ----> PUNCT ::::: ,
# here ----> ADV ::::: here
# I ----> PRON ::::: I
# was ----> AUX ::::: be
# all ----> ADV ::::: all
# upset ----> ADJ ::::: upset
# over ----> ADP ::::: over
# nothing ----> PRON ::::: nothing
# ! ----> PUNCT ::::: !
# He ----> PRON ::::: he
# starts ----> VERB ::::: start
# eating ----> VERB ::::: eat
# cereal ----> NOUN ::::: cereal
# . ----> PUNCT ::::: .
# So ----> ADV ::::: so
# . ----> PUNCT ::::: .
# What ----> PRON ::::: what
# 's ----> AUX ::::: be
# the ----> DET ::::: the
# big ----> ADJ ::::: big
# news ----> NOUN ::::: news
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# Mrs. ----> PROPN ::::: Mrs.
# Baxter ----> PROPN ::::: Baxter
# : ----> PUNCT ::::: :
# Harry ----> PROPN ::::: Harry
# and ----> CCONJ ::::: and
# I ----> PRON ::::: I
# are ----> AUX ::::: be
# breaking ----> VERB ::::: break
# up ----> ADP ::::: up
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# ’s ----> PART ::::: ’s
# jaw ----> NOUN ::::: jaw
# drops ----> VERB ::::: drop
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# * ----> PUNCT ::::: *
# * ----> PUNCT ::::: *
# * ----> PUNCT ::::: *
#
#
#  ----> SPACE :::::
#
#
# Arthur ----> PROPN ::::: Arthur
# and ----> CCONJ ::::: and
# Buster ----> PROPN ::::: Buster
# sit ----> VERB ::::: sit
# in ----> ADP ::::: in
# the ----> DET ::::: the
# treehouse ----> NOUN ::::: treehouse
# making ----> VERB ::::: make
# paper ----> NOUN ::::: paper
# flyers ----> NOUN ::::: flyer
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Arthur ----> PROPN ::::: Arthur
# : ----> PUNCT ::::: :
# So ----> ADV ::::: so
# , ----> PUNCT ::::: ,
# why ----> SCONJ ::::: why
# are ----> AUX ::::: be
# they ----> PRON ::::: they
# breaking ----> VERB ::::: break
# up ----> ADP ::::: up
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# do ----> AUX ::::: do
# n't ----> PART ::::: not
# know ----> VERB ::::: know
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
# did ----> AUX ::::: do
# n't ----> PART ::::: not
# feel ----> VERB ::::: feel
# like ----> ADP ::::: like
# asking ----> VERB ::::: ask
# . ----> PUNCT ::::: .
# But ----> CCONJ ::::: but
# I ----> PRON ::::: I
# sure ----> ADV ::::: sure
# will ----> AUX ::::: will
# miss ----> VERB ::::: miss
# going ----> VERB ::::: go
# to ----> ADP ::::: to
# Grebe ----> PROPN ::::: Grebe
# games ----> NOUN ::::: game
# . ----> PUNCT ::::: .
# Harry ----> PROPN ::::: Harry
# and ----> CCONJ ::::: and
# I ----> PRON ::::: I
# have ----> AUX ::::: have
# been ----> AUX ::::: be
# following ----> VERB ::::: follow
# them ----> PRON ::::: they
# all ----> DET ::::: all
# season ----> NOUN ::::: season
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Flashback ----> PROPN ::::: Flashback
# : ----> PUNCT ::::: :
# The ----> DET ::::: the
# Grebes ----> PROPN ::::: Grebes
# are ----> AUX ::::: be
# playing ----> VERB ::::: play
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Announcer ----> NOUN ::::: announcer
# : ----> PUNCT ::::: :
# Bottom ----> PROPN ::::: Bottom
# of ----> ADP ::::: of
# the ----> DET ::::: the
# ninth ----> ADJ ::::: ninth
# and ----> CCONJ ::::: and
# the ----> DET ::::: the
# score ----> NOUN ::::: score
# is ----> AUX ::::: be
# tied ----> VERB ::::: tie
# . ----> PUNCT ::::: .
# If ----> SCONJ ::::: if
# the ----> DET ::::: the
# Elwood ----> PROPN ::::: Elwood
# City ----> PROPN ::::: City
# Green ----> PROPN ::::: Green
# - ----> PUNCT ::::: -
# tailed ----> VERB ::::: tail
# Grebes ----> PROPN ::::: Grebes
# make ----> VERB ::::: make
# this ----> PRON ::::: this
# out ----> ADP ::::: out
# then ----> ADV ::::: then
# we ----> PRON ::::: we
# go ----> VERB ::::: go
# to ----> ADP ::::: to
# extra ----> ADJ ::::: extra
# innings ----> NOUN ::::: inning
# and ----> CCONJ ::::: and
# they ----> PRON ::::: they
# have ----> VERB ::::: have
# a ----> DET ::::: a
# shot ----> NOUN ::::: shot
# at ----> ADP ::::: at
# breaking ----> VERB ::::: break
# a ----> DET ::::: a
# twenty ----> NUM ::::: twenty
# - ----> PUNCT ::::: -
# two ----> NUM ::::: two
# game ----> NOUN ::::: game
# losing ----> VERB ::::: lose
# streak ----> NOUN ::::: streak
# . ----> PUNCT ::::: .
# Can ----> AUX ::::: can
# they ----> PRON ::::: they
# do ----> VERB ::::: do
# it ----> PRON ::::: it
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# The ----> DET ::::: the
# Grebes ----> PROPN ::::: Grebes
# pitch ----> NOUN ::::: pitch
# . ----> PUNCT ::::: .
# The ----> DET ::::: the
# ball ----> NOUN ::::: ball
# rolls ----> VERB ::::: roll
# to ----> ADP ::::: to
# second ----> ADJ ::::: second
# base ----> NOUN ::::: base
# , ----> PUNCT ::::: ,
# where ----> SCONJ ::::: where
# the ----> DET ::::: the
# baseman ----> NOUN ::::: baseman
# gets ----> VERB ::::: get
# the ----> DET ::::: the
# ball ----> NOUN ::::: ball
# , ----> PUNCT ::::: ,
# but ----> CCONJ ::::: but
# does ----> VERB ::::: do
# nothing ----> PRON ::::: nothing
# with ----> ADP ::::: with
# it ----> PRON ::::: it
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Announcer ----> NOUN ::::: announcer
# : ----> PUNCT ::::: :
# Line ----> NOUN ::::: line
# drive ----> VERB ::::: drive
# to ----> ADP ::::: to
# second ----> ADJ ::::: second
# ! ----> PUNCT ::::: !
# Ebos ----> NOUN ::::: ebo
# Shmecter ----> PROPN ::::: Shmecter
# has ----> VERB ::::: have
# his ----> PRON ::::: his
# glove ----> NOUN ::::: glove
# on ----> ADP ::::: on
# it ----> PRON ::::: it
# and ----> CCONJ ::::: and
# he ----> PRON ::::: he
# has ----> VERB ::::: have
# a ----> DET ::::: a
# clear ----> ADJ ::::: clear
# throw ----> NOUN ::::: throw
# to ----> ADP ::::: to
# first ----> ADJ ::::: first
# ! ----> PUNCT ::::: !
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# Throw ----> VERB ::::: throw
# it ----> PRON ::::: it
# , ----> PUNCT ::::: ,
# Ebos ----> PROPN ::::: Ebos
# ! ----> PUNCT ::::: !
#
#
#  ----> SPACE :::::
#
#
# Harry ----> PROPN ::::: Harry
# Mills ----> PROPN ::::: Mills
# : ----> PUNCT ::::: :
# Get ----> VERB ::::: get
# ' ----> PUNCT ::::: '
# i ----> PRON ::::: I
# m ----> VERB ::::: m
# out ----> ADV ::::: out
# ! ----> PUNCT ::::: !
#
#
#  ----> SPACE :::::
#
#
# Ebos ----> PROPN ::::: Ebos
# throws ----> VERB ::::: throw
# the ----> DET ::::: the
# ball ----> NOUN ::::: ball
# way ----> NOUN ::::: way
# over ----> ADP ::::: over
# the ----> DET ::::: the
# first ----> ADJ ::::: first
# baseman ----> NOUN ::::: baseman
# ’s ----> PART ::::: ’s
# head ----> NOUN ::::: head
# . ----> PUNCT ::::: .
# It ----> PRON ::::: it
# bounces ----> VERB ::::: bounce
# off ----> ADP ::::: off
# an ----> DET ::::: an
# exit ----> NOUN ::::: exit
# sign ----> NOUN ::::: sign
# and ----> CCONJ ::::: and
# drops ----> VERB ::::: drop
# into ----> ADP ::::: into
# Harry ----> PROPN ::::: Harry
# ’s ----> PART ::::: ’s
# drink ----> NOUN ::::: drink
# . ----> PUNCT ::::: .
# The ----> DET ::::: the
# batter ----> NOUN ::::: batter
# runs ----> VERB ::::: run
# into ----> ADP ::::: into
# home ----> NOUN ::::: home
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Announcer ----> NOUN ::::: announcer
# : ----> PUNCT ::::: :
# Nope ----> INTJ ::::: nope
# . ----> PUNCT ::::: .
# Looks ----> VERB ::::: look
# like ----> ADP ::::: like
# Ebos ----> PROPN ::::: Ebos
# just ----> ADV ::::: just
# could ----> AUX ::::: could
# n't ----> PART ::::: not
# get ----> VERB ::::: get
# a ----> DET ::::: a
# grip ----> NOUN ::::: grip
# on ----> ADP ::::: on
# it ----> PRON ::::: it
# . ----> PUNCT ::::: .
# That ----> PRON ::::: that
# 's ----> AUX ::::: be
# going ----> VERB ::::: go
# to ----> PART ::::: to
# cost ----> VERB ::::: cost
# the ----> DET ::::: the
# Grebes ----> PROPN ::::: Grebes
# the ----> DET ::::: the
# game ----> NOUN ::::: game
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Crowd ----> NOUN ::::: crowd
# : ----> PUNCT ::::: :
# Booooooooo ----> PROPN ::::: Booooooooo
# ! ----> PUNCT ::::: !
#
#
#  ----> SPACE :::::
#
#
# Harry ----> PROPN ::::: Harry
# hands ----> VERB ::::: hand
# the ----> DET ::::: the
# ball ----> NOUN ::::: ball
# to ----> ADP ::::: to
# Buster ----> PROPN ::::: Buster
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# Woohoo ----> INTJ ::::: woohoo
# ! ----> PUNCT ::::: !
# I ----> PRON ::::: I
# got ----> VERB ::::: get
# the ----> DET ::::: the
# losing ----> NOUN ::::: losing
# ball ----> NOUN ::::: ball
# ! ----> PUNCT ::::: !
#
#
#  ----> SPACE :::::
#
#
# The ----> DET ::::: the
# flashback ----> NOUN ::::: flashback
# ends ----> VERB ::::: end
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# They ----> PRON ::::: they
# still ----> ADV ::::: still
# have ----> AUX ::::: have
# n't ----> PART ::::: not
# won ----> VERB ::::: win
# a ----> DET ::::: a
# game ----> NOUN ::::: game
# . ----> PUNCT ::::: .
# But ----> CCONJ ::::: but
# Harry ----> PROPN ::::: Harry
# and ----> CCONJ ::::: and
# I ----> PRON ::::: I
# always ----> ADV ::::: always
# had ----> VERB ::::: have
# a ----> DET ::::: a
# great ----> ADJ ::::: great
# time ----> NOUN ::::: time
# going ----> VERB ::::: go
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Arthur ----> PROPN ::::: Arthur
# : ----> PUNCT ::::: :
# Ca ----> AUX ::::: can
# n't ----> PART ::::: not
# you ----> PRON ::::: you
# go ----> VERB ::::: go
# with ----> ADP ::::: with
# your ----> PRON ::::: your
# mom ----> NOUN ::::: mom
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# Nah ----> PROPN ::::: Nah
# . ----> PUNCT ::::: .
# She ----> PRON ::::: she
# does ----> AUX ::::: do
# n't ----> PART ::::: not
# like ----> VERB ::::: like
# baseball ----> NOUN ::::: baseball
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Arthur ----> PROPN ::::: Arthur
# : ----> PUNCT ::::: :
# Well ----> INTJ ::::: well
# , ----> PUNCT ::::: ,
# maybe ----> ADV ::::: maybe
# she ----> PRON ::::: she
# 'll ----> AUX ::::: will
# get ----> VERB ::::: get
# another ----> DET ::::: another
# boyfriend ----> NOUN ::::: boyfriend
# who ----> PRON ::::: who
# does ----> VERB ::::: do
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# A ----> DET ::::: a
# new ----> ADJ ::::: new
# boyfriend ----> NOUN ::::: boyfriend
# ? ----> PUNCT ::::: ?
# Y ----> PROPN ::::: Y
# - ----> PUNCT ::::: -
# you ----> PRON ::::: you
# think ----> VERB ::::: think
# she ----> PRON ::::: she
# 's ----> AUX ::::: be
# gon ----> VERB ::::: go
# na ----> PART ::::: to
# get ----> VERB ::::: get
# a ----> DET ::::: a
# new ----> ADJ ::::: new
# boyfriend ----> NOUN ::::: boyfriend
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# Arthur ----> PROPN ::::: Arthur
# : ----> PUNCT ::::: :
# Well ----> INTJ ::::: well
# ... ----> PUNCT ::::: ...
# I ----> PRON ::::: I
# do ----> AUX ::::: do
# n't ----> PART ::::: not
# know ----> VERB ::::: know
# . ----> PUNCT ::::: .
# She ----> PRON ::::: she
# could ----> AUX ::::: could
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# No ----> INTJ ::::: no
# ! ----> PUNCT ::::: !
# She ----> PRON ::::: she
# ca ----> AUX ::::: can
# n't ----> PART ::::: not
# ! ----> PUNCT ::::: !
# I ----> PRON ::::: I
# - ----> PUNCT ::::: -
# I ----> PRON ::::: I
# mean ----> VERB ::::: mean
# , ----> PUNCT ::::: ,
# it ----> PRON ::::: it
# took ----> VERB ::::: take
# me ----> PRON ::::: I
# a ----> DET ::::: a
# long ----> ADJ ::::: long
# time ----> NOUN ::::: time
# to ----> PART ::::: to
# get ----> VERB ::::: get
# used ----> VERB ::::: use
# to ----> ADP ::::: to
# Harry ----> PROPN ::::: Harry
# . ----> PUNCT ::::: .
# And ----> CCONJ ::::: and
# what ----> PRON ::::: what
# if ----> SCONJ ::::: if
# her ----> PRON ::::: her
# new ----> ADJ ::::: new
# boyfriend ----> NOUN ::::: boyfriend
# is ----> AUX ::::: be
# really ----> ADV ::::: really
# boring ----> ADJ ::::: boring
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# sees ----> VERB ::::: see
# himself ----> PRON ::::: himself
# and ----> CCONJ ::::: and
# his ----> PRON ::::: his
# mom ----> NOUN ::::: mom
# having ----> VERB ::::: have
# dinner ----> NOUN ::::: dinner
# at ----> ADP ::::: at
# home ----> NOUN ::::: home
# with ----> ADP ::::: with
# a ----> DET ::::: a
# man ----> NOUN ::::: man
# in ----> ADP ::::: in
# a ----> DET ::::: a
# suit ----> NOUN ::::: suit
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Mrs. ----> PROPN ::::: Mrs.
# Baxter ----> PROPN ::::: Baxter
# : ----> PUNCT ::::: :
# Martin ----> PROPN ::::: Martin
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# was ----> AUX ::::: be
# thinking ----> VERB ::::: think
# you ----> PRON ::::: you
# could ----> AUX ::::: could
# spend ----> VERB ::::: spend
# some ----> DET ::::: some
# time ----> NOUN ::::: time
# with ----> ADP ::::: with
# Buster ----> PROPN ::::: Buster
# tomorrow ----> NOUN ::::: tomorrow
# . ----> PUNCT ::::: .
# Maybe ----> ADV ::::: maybe
# show ----> VERB ::::: show
# him ----> PRON ::::: he
# where ----> SCONJ ::::: where
# you ----> PRON ::::: you
# work ----> VERB ::::: work
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Martin ----> PROPN ::::: Martin
# Spivak ----> PROPN ::::: Spivak
# : ----> PUNCT ::::: :
# Aww ----> PROPN ::::: Aww
# ... ----> PUNCT ::::: ...
# do ----> AUX ::::: do
# I ----> PRON ::::: I
# have ----> VERB ::::: have
# to ----> PART ::::: to
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# looks ----> VERB ::::: look
# horrified ----> ADJ ::::: horrified
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Still ----> ADV ::::: still
# in ----> ADP ::::: in
# the ----> DET ::::: the
# fantasy ----> NOUN ::::: fantasy
# , ----> PUNCT ::::: ,
# Martin ----> PROPN ::::: Martin
# leads ----> VERB ::::: lead
# Buster ----> PROPN ::::: Buster
# through ----> ADP ::::: through
# a ----> DET ::::: a
# large ----> ADJ ::::: large
# office ----> NOUN ::::: office
# and ----> CCONJ ::::: and
# into ----> ADP ::::: into
# a ----> DET ::::: a
# cubicle ----> NOUN ::::: cubicle
# . ----> PUNCT ::::: .
# A ----> DET ::::: a
# phone ----> NOUN ::::: phone
# rings ----> NOUN ::::: ring
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Martin ----> PROPN ::::: Martin
# Spivak ----> PROPN ::::: Spivak
# : ----> PUNCT ::::: :
# Sit ----> VERB ::::: sit
# there ----> ADV ::::: there
# , ----> PUNCT ::::: ,
# do ----> AUX ::::: do
# n't ----> PART ::::: not
# touch ----> VERB ::::: touch
# anything ----> PRON ::::: anything
# . ----> PUNCT ::::: .
# What ----> DET ::::: what
# time ----> NOUN ::::: time
# is ----> AUX ::::: be
# it ----> PRON ::::: it
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# Six ----> NUM ::::: six
# o’clock ----> NOUN ::::: o’clock
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Martin ----> PROPN ::::: Martin
# Spivak ----> PROPN ::::: Spivak
# : ----> PUNCT ::::: :
# Dinner ----> PROPN ::::: Dinner
# time ----> NOUN ::::: time
# ... ----> PUNCT ::::: ...
# perfect ----> ADJ ::::: perfect
# . ----> PUNCT ::::: .
# He ----> PRON ::::: he
# puts ----> VERB ::::: put
# on ----> ADP ::::: on
# headphones ----> NOUN ::::: headphone
# . ----> PUNCT ::::: .
# Good ----> ADJ ::::: good
# evening ----> NOUN ::::: evening
# , ----> PUNCT ::::: ,
# Mrs. ----> PROPN ::::: Mrs.
# Abigail ----> PROPN ::::: Abigail
# Adams ----> PROPN ::::: Adams
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# Martin ----> PROPN ::::: Martin
# Spivak ----> PROPN ::::: Spivak
# of ----> ADP ::::: of
# Never ----> PROPN ::::: Never
# Better ----> PROPN ::::: Better
# Insurance ----> PROPN ::::: Insurance
# . ----> PUNCT ::::: .
# Does ----> VERB ::::: do
# your ----> PRON ::::: your
# homeowner ----> NOUN ::::: homeowner
# 's ----> PART ::::: 's
# policy ----> NOUN ::::: policy
# cover ----> NOUN ::::: cover
# mudslides ----> NOUN ::::: mudslide
# , ----> PUNCT ::::: ,
# locusts ----> NOUN ::::: locust
# , ----> PUNCT ::::: ,
# and ----> CCONJ ::::: and
# killer ----> NOUN ::::: killer
# mold ----> NOUN ::::: mold
# ? ----> PUNCT ::::: ?
# He ----> PRON ::::: he
# puts ----> VERB ::::: put
# down ----> ADP ::::: down
# the ----> DET ::::: the
# phone ----> NOUN ::::: phone
# and ----> CCONJ ::::: and
# takes ----> VERB ::::: take
# off ----> ADP ::::: off
# the ----> DET ::::: the
# headphone ----> NOUN ::::: headphone
# while ----> SCONJ ::::: while
# the ----> DET ::::: the
# lady ----> NOUN ::::: lady
# at ----> ADP ::::: at
# the ----> DET ::::: the
# other ----> ADJ ::::: other
# end ----> NOUN ::::: end
# talks ----> NOUN ::::: talk
# incomprehensibly ----> ADV ::::: incomprehensibly
# . ----> PUNCT ::::: .
# Martin ----> PROPN ::::: Martin
# opens ----> VERB ::::: open
# a ----> DET ::::: a
# book ----> NOUN ::::: book
# . ----> PUNCT ::::: .
# ( ----> PUNCT ::::: (
# yawns ----> VERB ::::: yawn
# ) ----> PUNCT ::::: )
# Coffee ----> PROPN ::::: Coffee
# 's ----> PART ::::: 's
# past ----> NOUN ::::: past
# the ----> DET ::::: the
# copy ----> NOUN ::::: copy
# machine ----> NOUN ::::: machine
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
# take ----> VERB ::::: take
# it ----> PRON ::::: it
# black ----> ADJ ::::: black
# , ----> PUNCT ::::: ,
# five ----> NUM ::::: five
# sugars ----> NOUN ::::: sugar
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# looks ----> VERB ::::: look
# horrified ----> ADJ ::::: horrified
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# The ----> DET ::::: the
# fantasy ----> NOUN ::::: fantasy
# ends ----> VERB ::::: end
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# hate ----> VERB ::::: hate
# Martin ----> PROPN ::::: Martin
# Spivak ----> PROPN ::::: Spivak
# ! ----> PUNCT ::::: !
#
#
#  ----> SPACE :::::
#
#
# Arthur ----> PROPN ::::: Arthur
# : ----> PUNCT ::::: :
# Who ----> PRON ::::: who
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# Aw ----> INTJ ::::: aw
# , ----> PUNCT ::::: ,
# never ----> ADV ::::: never
# mind ----> NOUN ::::: mind
# , ----> PUNCT ::::: ,
# Arthur ----> PROPN ::::: Arthur
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
# ca ----> AUX ::::: can
# n't ----> PART ::::: not
# let ----> VERB ::::: let
# Harry ----> PROPN ::::: Harry
# break ----> VERB ::::: break
# up ----> ADP ::::: up
# with ----> ADP ::::: with
# my ----> PRON ::::: my
# mom ----> NOUN ::::: mom
# ! ----> PUNCT ::::: !
# She ----> PRON ::::: she
# has ----> VERB ::::: have
# to ----> PART ::::: to
# win ----> VERB ::::: win
# him ----> PRON ::::: he
# back ----> ADV ::::: back
# ! ----> PUNCT ::::: !
#
#
#  ----> SPACE :::::
#
#
# He ----> PRON ::::: he
# climbs ----> VERB ::::: climb
# down ----> ADP ::::: down
# the ----> DET ::::: the
# ladder ----> NOUN ::::: ladder
# . ----> PUNCT ::::: .
# Arthur ----> PROPN ::::: Arthur
# looks ----> VERB ::::: look
# down ----> ADP ::::: down
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Arthur ----> PROPN ::::: Arthur
# : ----> PUNCT ::::: :
# Buster ----> PROPN ::::: Buster
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# should ----> AUX ::::: should
# n't ----> PART ::::: not
# get ----> AUX ::::: get
# involved ----> VERB ::::: involve
# ! ----> PUNCT ::::: !
# Besides ----> ADV ::::: besides
# , ----> PUNCT ::::: ,
# how ----> SCONJ ::::: how
# on ----> ADP ::::: on
# Earth ----> PROPN ::::: Earth
# could ----> AUX ::::: could
# you ----> PRON ::::: you
# change ----> VERB ::::: change
# Harry ----> PROPN ::::: Harry
# 's ----> PART ::::: 's
# mind ----> NOUN ::::: mind
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# By ----> ADP ::::: by
# going ----> VERB ::::: go
# to ----> ADP ::::: to
# an ----> DET ::::: an
# expert ----> NOUN ::::: expert
# ! ----> PUNCT ::::: !
#
#
#  ----> SPACE :::::
#
#
# He ----> PRON ::::: he
# runs ----> VERB ::::: run
# off ----> ADP ::::: off
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# * ----> PUNCT ::::: *
# * ----> PUNCT ::::: *
# * ----> PUNCT ::::: *
#
#
#  ----> SPACE :::::
#
#
# Muffy ----> PROPN ::::: Muffy
# sits ----> VERB ::::: sit
# on ----> ADP ::::: on
# her ----> PRON ::::: her
# bed ----> NOUN ::::: bed
# and ----> CCONJ ::::: and
# paints ----> VERB ::::: paint
# her ----> PRON ::::: her
# toenails ----> NOUN ::::: toenail
# . ----> PUNCT ::::: .
# Buster ----> PROPN ::::: Buster
# sits ----> VERB ::::: sit
# in ----> ADP ::::: in
# an ----> DET ::::: an
# armchair ----> NOUN ::::: armchair
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Muffy ----> PROPN ::::: Muffy
# : ----> PUNCT ::::: :
# So ----> ADV ::::: so
# , ----> PUNCT ::::: ,
# let ----> VERB ::::: let
# me ----> PRON ::::: I
# get ----> VERB ::::: get
# this ----> DET ::::: this
# straight ----> ADJ ::::: straight
# , ----> PUNCT ::::: ,
# the ----> DET ::::: the
# love ----> NOUN ::::: love
# of ----> ADP ::::: of
# your ----> PRON ::::: your
# life ----> NOUN ::::: life
# just ----> ADV ::::: just
# crushed ----> VERB ::::: crush
# your ----> PRON ::::: your
# heart ----> NOUN ::::: heart
# and ----> CCONJ ::::: and
# now ----> ADV ::::: now
# you ----> PRON ::::: you
# 're ----> AUX ::::: be
# willing ----> ADJ ::::: willing
# to ----> PART ::::: to
# do ----> VERB ::::: do
# anything ----> PRON ::::: anything
# to ----> PART ::::: to
# get ----> VERB ::::: get
# her ----> PRON ::::: she
# back ----> ADV ::::: back
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# No ----> INTJ ::::: no
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# told ----> VERB ::::: tell
# you ----> PRON ::::: you
# ! ----> PUNCT ::::: !
# This ----> PRON ::::: this
# is ----> AUX ::::: be
# all ----> ADV ::::: all
# about ----> ADP ::::: about
# my ----> PRON ::::: my
# mother ----> NOUN ::::: mother
# ! ----> PUNCT ::::: !
#
#
#  ----> SPACE :::::
#
#
# Muffy ----> PROPN ::::: Muffy
# : ----> PUNCT ::::: :
# Oh ----> INTJ ::::: oh
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# understand ----> VERB ::::: understand
# . ----> PUNCT ::::: .
# This ----> PRON ::::: this
# is ----> AUX ::::: be
# your ----> PRON ::::: your
# “ ----> PUNCT ::::: "
# mother ----> NOUN ::::: mother
# 's ----> PART ::::: 's
# ” ----> PUNCT ::::: "
# problem ----> NOUN ::::: problem
# . ----> PUNCT ::::: .
# She ----> PRON ::::: she
# mimics ----> VERB ::::: mimic
# quotation ----> NOUN ::::: quotation
# marks ----> NOUN ::::: mark
# . ----> PUNCT ::::: .
# Do ----> AUX ::::: do
# n't ----> PART ::::: not
# worry ----> VERB ::::: worry
# , ----> PUNCT ::::: ,
# your ----> PRON ::::: your
# secret ----> NOUN ::::: secret
# 's ----> PART ::::: 's
# safe ----> ADJ ::::: safe
# with ----> ADP ::::: with
# me ----> PRON ::::: I
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# What ----> PRON ::::: what
# secret ----> ADJ ::::: secret
# ? ----> PUNCT ::::: ?
# There ----> PRON ::::: there
# 's ----> VERB ::::: be
# no ----> DET ::::: no
# secret ----> ADJ ::::: secret
# ! ----> PUNCT ::::: !
#
#
#  ----> SPACE :::::
#
#
# Muffy ----> PROPN ::::: Muffy
# : ----> PUNCT ::::: :
# Well ----> INTJ ::::: well
# I ----> PRON ::::: I
# always ----> ADV ::::: always
# say ----> VERB ::::: say
# , ----> PUNCT ::::: ,
# nothing ----> PRON ::::: nothing
# impresses ----> VERB ::::: impress
# that ----> SCONJ ::::: that
# special ----> ADJ ::::: special
# someone ----> PRON ::::: someone
# like ----> ADP ::::: like
# a ----> DET ::::: a
# romantic ----> ADJ ::::: romantic
# dinner ----> NOUN ::::: dinner
# with ----> ADP ::::: with
# candles ----> NOUN ::::: candle
# , ----> PUNCT ::::: ,
# flowers ----> NOUN ::::: flower
# , ----> PUNCT ::::: ,
# the ----> DET ::::: the
# works ----> NOUN ::::: work
# ! ----> PUNCT ::::: !
# Here ----> ADV ::::: here
# ... ----> PUNCT ::::: ...
# You ----> PRON ::::: you
# 'll ----> AUX ::::: will
# find ----> VERB ::::: find
# all ----> DET ::::: all
# the ----> DET ::::: the
# ingredients ----> NOUN ::::: ingredient
# in ----> ADP ::::: in
# the ----> DET ::::: the
# February ----> PROPN ::::: February
# issue ----> NOUN ::::: issue
# of ----> ADP ::::: of
# Tween ----> PROPN ::::: Tween
# Queen ----> PROPN ::::: Queen
# magazine ----> NOUN ::::: magazine
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# She ----> PRON ::::: she
# takes ----> VERB ::::: take
# the ----> DET ::::: the
# magazine ----> NOUN ::::: magazine
# off ----> ADP ::::: off
# a ----> DET ::::: a
# shelf ----> NOUN ::::: shelf
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# A ----> DET ::::: a
# romantic ----> ADJ ::::: romantic
# dinner ----> NOUN ::::: dinner
# ? ----> PUNCT ::::: ?
# But ----> CCONJ ::::: but
# I ----> PRON ::::: I
# ca ----> AUX ::::: can
# n't ----> PART ::::: not
# cook ----> VERB ::::: cook
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Muffy ----> PROPN ::::: Muffy
# : ----> PUNCT ::::: :
# So ----> ADV ::::: so
# ? ----> PUNCT ::::: ?
# Have ----> AUX ::::: have
# it ----> PRON ::::: it
# catered ----> VERB ::::: cater
# . ----> PUNCT ::::: .
# Try ----> VERB ::::: try
# Trattoria ----> PROPN ::::: Trattoria
# Molto ----> PROPN ::::: Molto
# Dinaro ----> PROPN ::::: Dinaro
# . ----> PUNCT ::::: .
# They ----> PRON ::::: they
# do ----> VERB ::::: do
# a ----> DET ::::: a
# divine ----> ADJ ::::: divine
# penne ----> NOUN ::::: penne
# bolognese ----> NOUN ::::: bolognese
# . ----> PUNCT ::::: .
# Is ----> AUX ::::: be
# it ----> PRON ::::: it
# Sue ----> PROPN ::::: Sue
# Ellen ----> PROPN ::::: Ellen
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# No ----> PROPN ::::: No
# ! ----> PUNCT ::::: !
#
#
#  ----> SPACE :::::
#
#
# He ----> PRON ::::: he
# leaves ----> VERB ::::: leave
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# * ----> PUNCT ::::: *
# * ----> PUNCT ::::: *
# * ----> PUNCT ::::: *
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# sits ----> VERB ::::: sit
# at ----> ADP ::::: at
# his ----> PRON ::::: his
# desk ----> NOUN ::::: desk
# with ----> ADP ::::: with
# a ----> DET ::::: a
# typewriter ----> NOUN ::::: typewriter
# in ----> ADP ::::: in
# front ----> NOUN ::::: front
# of ----> ADP ::::: of
# him ----> PRON ::::: he
# . ----> PUNCT ::::: .
# He ----> PRON ::::: he
# reads ----> VERB ::::: read
# Tween ----> PROPN ::::: Tween
# Magazine ----> PROPN ::::: Magazine
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# “ ----> PUNCT ::::: "
# Step ----> PROPN ::::: Step
# One ----> NUM ::::: one
# . ----> PUNCT ::::: .
# Surprise ----> VERB ::::: surprise
# him ----> PRON ::::: he
# with ----> ADP ::::: with
# a ----> DET ::::: a
# mysterious ----> ADJ ::::: mysterious
# invitation ----> NOUN ::::: invitation
# . ----> PUNCT ::::: .
# ” ----> PUNCT ::::: "
#
#
#  ----> SPACE :::::
#
#
# In ----> ADP ::::: in
# his ----> PRON ::::: his
# mom ----> NOUN ::::: mom
# ’s ----> PART ::::: ’s
# bedroom ----> NOUN ::::: bedroom
# , ----> PUNCT ::::: ,
# Buster ----> PROPN ::::: Buster
# sprays ----> VERB ::::: spray
# some ----> PRON ::::: some
# of ----> ADP ::::: of
# her ----> PRON ::::: her
# perfume ----> NOUN ::::: perfume
# on ----> ADP ::::: on
# the ----> DET ::::: the
# letter ----> NOUN ::::: letter
# . ----> PUNCT ::::: .
# He ----> PRON ::::: he
# sniffs ----> VERB ::::: sniff
# it ----> PRON ::::: it
# , ----> PUNCT ::::: ,
# then ----> ADV ::::: then
# he ----> PRON ::::: he
# screws ----> VERB ::::: screw
# off ----> ADP ::::: off
# the ----> DET ::::: the
# lid ----> NOUN ::::: lid
# and ----> CCONJ ::::: and
# pours ----> VERB ::::: pour
# the ----> DET ::::: the
# whole ----> ADJ ::::: whole
# bottle ----> NOUN ::::: bottle
# over ----> ADP ::::: over
# it ----> PRON ::::: it
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# * ----> PUNCT ::::: *
# * ----> PUNCT ::::: *
# * ----> PUNCT ::::: *
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# walks ----> VERB ::::: walk
# into ----> ADP ::::: into
# the ----> DET ::::: the
# Elwood ----> PROPN ::::: Elwood
# City ----> PROPN ::::: City
# Times ----> PROPN ::::: Times
# building ----> NOUN ::::: building
# . ----> PUNCT ::::: .
# His ----> PRON ::::: his
# mother ----> NOUN ::::: mother
# walks ----> VERB ::::: walk
# down ----> ADP ::::: down
# the ----> DET ::::: the
# hallways ----> NOUN ::::: hallway
# with ----> ADP ::::: with
# some ----> DET ::::: some
# colleagues ----> NOUN ::::: colleague
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Mrs. ----> PROPN ::::: Mrs.
# Baxter ----> PROPN ::::: Baxter
# : ----> PUNCT ::::: :
# Grant ----> PROPN ::::: Grant
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# 're ----> AUX ::::: be
# on ----> ADP ::::: on
# the ----> DET ::::: the
# Philadelphia ----> PROPN ::::: Philadelphia
# story ----> NOUN ::::: story
# . ----> PUNCT ::::: .
# Russell ----> PROPN ::::: Russell
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# 're ----> AUX ::::: be
# doing ----> VERB ::::: do
# the ----> DET ::::: the
# front ----> ADJ ::::: front
# page ----> NOUN ::::: page
# . ----> PUNCT ::::: .
# Parker ----> PROPN ::::: Parker
# , ----> PUNCT ::::: ,
# get ----> VERB ::::: get
# me ----> PRON ::::: I
# some ----> DET ::::: some
# photos ----> NOUN ::::: photo
# of ----> ADP ::::: of
# the ----> DET ::::: the
# new ----> ADJ ::::: new
# bug ----> NOUN ::::: bug
# wing ----> NOUN ::::: wing
# at ----> ADP ::::: at
# the ----> DET ::::: the
# museum ----> NOUN ::::: museum
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# hides ----> VERB ::::: hide
# behind ----> ADP ::::: behind
# a ----> DET ::::: a
# pillar ----> NOUN ::::: pillar
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# puts ----> VERB ::::: put
# on ----> ADP ::::: on
# a ----> DET ::::: a
# hat ----> NOUN ::::: hat
# and ----> CCONJ ::::: and
# a ----> DET ::::: a
# fake ----> ADJ ::::: fake
# elephant ----> NOUN ::::: elephant
# ’s ----> PART ::::: ’s
# trunk ----> NOUN ::::: trunk
# . ----> PUNCT ::::: .
# He ----> PRON ::::: he
# sneaks ----> VERB ::::: sneak
# into ----> ADP ::::: into
# Harry ----> PROPN ::::: Harry
# ’s ----> PART ::::: ’s
# cubicle ----> NOUN ::::: cubicle
# and ----> CCONJ ::::: and
# puts ----> VERB ::::: put
# an ----> DET ::::: an
# envelope ----> NOUN ::::: envelope
# on ----> ADP ::::: on
# the ----> DET ::::: the
# desk ----> NOUN ::::: desk
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# A ----> DET ::::: a
# little ----> ADJ ::::: little
# later ----> ADV ::::: later
# Harry ----> PROPN ::::: Harry
# opens ----> VERB ::::: open
# the ----> DET ::::: the
# envelope ----> NOUN ::::: envelope
# which ----> PRON ::::: which
# emits ----> VERB ::::: emit
# a ----> DET ::::: a
# strong ----> ADJ ::::: strong
# smell ----> NOUN ::::: smell
# of ----> ADP ::::: of
# perfume ----> NOUN ::::: perfume
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Harry ----> PROPN ::::: Harry
# Mills ----> PROPN ::::: Mills
# : ----> PUNCT ::::: :
# ( ----> PUNCT ::::: (
# sneezes ----> VERB ::::: sneeze
# ) ----> PUNCT ::::: )
# " ----> PUNCT ::::: "
# You ----> PRON ::::: you
# are ----> AUX ::::: be
# invited ----> VERB ::::: invite
# to ----> ADP ::::: to
# a ----> DET ::::: a
# romantic ----> ADJ ::::: romantic
# diner ----> NOUN ::::: diner
# tonight ----> NOUN ::::: tonight
# . ----> PUNCT ::::: .
# Baxter ----> PROPN ::::: Baxter
# residence ----> NOUN ::::: residence
# . ----> PUNCT ::::: .
# 7 ----> NUM ::::: 7
# pm ----> NOUN ::::: pm
# . ----> PUNCT ::::: .
# ...
# we ----> PRON ::::: we
# both ----> PRON ::::: both
# have ----> VERB ::::: have
# very ----> ADV ::::: very
# heavy ----> ADJ ::::: heavy
# schedules ----> NOUN ::::: schedule
# , ----> PUNCT ::::: ,
# and ----> CCONJ ::::: and
# ... ----> PUNCT ::::: ...
# Buster ----> PROPN ::::: Buster
# , ----> PUNCT ::::: ,
# ca ----> AUX ::::: can
# n't ----> PART ::::: not
# we ----> PRON ::::: we
# talk ----> VERB ::::: talk
# about ----> ADP ::::: about
# it ----> PRON ::::: it
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# keeps ----> VERB ::::: keep
# on ----> ADP ::::: on
# walking ----> VERB ::::: walk
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# * ----> PUNCT ::::: *
# * ----> PUNCT ::::: *
# * ----> PUNCT ::::: *
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# and ----> CCONJ ::::: and
# Bitzi ----> PROPN ::::: Bitzi
# sit ----> VERB ::::: sit
# on ----> ADP ::::: on
# Buster ----> PROPN ::::: Buster
# ’s ----> PART ::::: ’s
# bed ----> NOUN ::::: bed
# . ----> PUNCT ::::: .
# The ----> DET ::::: the
# pie ----> NOUN ::::: pie
# and ----> CCONJ ::::: and
# the ----> DET ::::: the
# pizza ----> NOUN ::::: pizza
# box ----> NOUN ::::: box
# are ----> AUX ::::: be
# lying ----> VERB ::::: lie
# there ----> ADV ::::: there
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Mrs. ----> PROPN ::::: Mrs.
# Baxter ----> PROPN ::::: Baxter
# : ----> PUNCT ::::: :
# So ----> ADV ::::: so
# , ----> PUNCT ::::: ,
# it ----> PRON ::::: it
# has ----> VERB ::::: have
# nothing ----> PRON ::::: nothing
# to ----> PART ::::: to
# do ----> VERB ::::: do
# with ----> ADP ::::: with
# you ----> PRON ::::: you
# , ----> PUNCT ::::: ,
# dear ----> ADJ ::::: dear
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# just ----> ADV ::::: just
# too ----> ADV ::::: too
# busy ----> ADJ ::::: busy
# for ----> ADP ::::: for
# a ----> DET ::::: a
# relationship ----> NOUN ::::: relationship
# right ----> ADV ::::: right
# now ----> ADV ::::: now
# . ----> PUNCT ::::: .
# Do ----> AUX ::::: do
# you ----> PRON ::::: you
# understand ----> VERB ::::: understand
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# No ----> INTJ ::::: no
# , ----> PUNCT ::::: ,
# not ----> PART ::::: not
# really ----> ADV ::::: really
# . ----> PUNCT ::::: .
# He ----> PRON ::::: he
# kisses ----> VERB ::::: kiss
# her ----> PRON ::::: she
# . ----> PUNCT ::::: .
# But ----> CCONJ ::::: but
# it ----> PRON ::::: it
# 's ----> AUX ::::: be
# okay ----> ADJ ::::: okay
# . ----> PUNCT ::::: .
# He ----> PRON ::::: he
# lies ----> VERB ::::: lie
# down ----> ADP ::::: down
# . ----> PUNCT ::::: .
# ( ----> PUNCT ::::: (
# sighs ----> VERB ::::: sigh
# ) ----> PUNCT ::::: )
# I ----> PRON ::::: I
# 'll ----> AUX ::::: will
# get ----> VERB ::::: get
# over ----> ADP ::::: over
# it ----> PRON ::::: it
# . ----> PUNCT ::::: .
# Good ----> ADJ ::::: good
# night ----> NOUN ::::: night
# , ----> PUNCT ::::: ,
# Mom ----> PROPN ::::: Mom
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Mrs. ----> PROPN ::::: Mrs.
# Baxter ----> PROPN ::::: Baxter
# : ----> PUNCT ::::: :
# Good ----> PROPN ::::: Good
# night ----> NOUN ::::: night
# , ----> PUNCT ::::: ,
# sweetie ----> NOUN ::::: sweetie
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# She ----> PRON ::::: she
# goes ----> VERB ::::: go
# out ----> ADP ::::: out
# with ----> ADP ::::: with
# the ----> DET ::::: the
# food ----> NOUN ::::: food
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# Mom ----> PROPN ::::: Mom
# ? ----> PUNCT ::::: ?
# Could ----> AUX ::::: could
# you ----> PRON ::::: you
# leave ----> VERB ::::: leave
# the ----> DET ::::: the
# pie ----> NOUN ::::: pie
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# She ----> PRON ::::: she
# puts ----> VERB ::::: put
# it ----> PRON ::::: it
# on ----> ADP ::::: on
# a ----> DET ::::: a
# cupboard ----> NOUN ::::: cupboard
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# * ----> PUNCT ::::: *
# * ----> PUNCT ::::: *
# * ----> PUNCT ::::: *
#
#
#  ----> SPACE :::::
#
#
# Muffy ----> PROPN ::::: Muffy
# meets ----> VERB ::::: meet
# Buster ----> PROPN ::::: Buster
# at ----> ADP ::::: at
# his ----> PRON ::::: his
# locker ----> NOUN ::::: locker
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Muffy ----> PROPN ::::: Muffy
# : ----> PUNCT ::::: :
# So ----> ADV ::::: so
# , ----> PUNCT ::::: ,
# did ----> AUX ::::: do
# Sue ----> PROPN ::::: Sue
# Ellen ----> PROPN ::::: Ellen
# fall ----> VERB ::::: fall
# for ----> ADP ::::: for
# it ----> PRON ::::: it
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# Once ----> ADV ::::: once
# and ----> CCONJ ::::: and
# for ----> ADP ::::: for
# all ----> PRON ::::: all
# , ----> PUNCT ::::: ,
# it ----> PRON ::::: it
# was ----> AUX ::::: be
# n't ----> PART ::::: not
# for ----> ADP ::::: for
# Sue ----> PROPN ::::: Sue
# Ellen ----> PROPN ::::: Ellen
# ! ----> PUNCT ::::: !
#
#
#  ----> SPACE :::::
#
#
# Muffy ----> PROPN ::::: Muffy
# : ----> PUNCT ::::: :
# Oh ----> INTJ ::::: oh
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# And ----> CCONJ ::::: and
# the ----> DET ::::: the
# whole ----> ADJ ::::: whole
# thing ----> NOUN ::::: thing
# was ----> AUX ::::: be
# a ----> DET ::::: a
# complete ----> ADJ ::::: complete
# disaster ----> NOUN ::::: disaster
# . ----> PUNCT ::::: .
# Here ----> ADV ::::: here
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# can ----> AUX ::::: can
# have ----> VERB ::::: have
# your ----> PRON ::::: your
# magazine ----> NOUN ::::: magazine
# back ----> ADV ::::: back
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# He ----> PRON ::::: he
# hands ----> VERB ::::: hand
# it ----> PRON ::::: it
# back ----> ADV ::::: back
# . ----> PUNCT ::::: .
# They ----> PRON ::::: they
# walk ----> VERB ::::: walk
# out ----> ADP ::::: out
# of ----> ADP ::::: of
# school ----> NOUN ::::: school
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Muffy ----> PROPN ::::: Muffy
# : ----> PUNCT ::::: :
# The ----> DET ::::: the
# heart ----> NOUN ::::: heart
# is ----> AUX ::::: be
# mysterious ----> ADJ ::::: mysterious
# , ----> PUNCT ::::: ,
# Buster ----> PROPN ::::: Buster
# . ----> PUNCT ::::: .
# Look ----> VERB ::::: look
# at ----> ADP ::::: at
# me ----> PRON ::::: I
# and ----> CCONJ ::::: and
# the ----> DET ::::: the
# Backstreet ----> PROPN ::::: Backstreet
# Boys ----> PROPN ::::: Boys
# . ----> PUNCT ::::: .
# First ----> ADV ::::: first
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# thought ----> VERB ::::: think
# I ----> PRON ::::: I
# loved ----> VERB ::::: love
# Nick ----> PROPN ::::: Nick
# , ----> PUNCT ::::: ,
# then ----> ADV ::::: then
# Howie ----> PROPN ::::: Howie
# , ----> PUNCT ::::: ,
# when ----> SCONJ ::::: when
# all ----> PRON ::::: all
# along ----> ADV ::::: along
# it ----> PRON ::::: it
# was ----> AUX ::::: be
# A.J. ----> PROPN ::::: A.J.
# who ----> PRON ::::: who
# was ----> AUX ::::: be
# meant ----> VERB ::::: mean
# for ----> ADP ::::: for
# me ----> PRON ::::: I
# . ----> PUNCT ::::: .
# Who ----> PRON ::::: who
# knew ----> VERB ::::: know
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# She ----> PRON ::::: she
# gets ----> VERB ::::: get
# in ----> ADP ::::: in
# her ----> PRON ::::: her
# limo ----> NOUN ::::: limo
# and ----> CCONJ ::::: and
# drives ----> VERB ::::: drive
# off ----> ADP ::::: off
# . ----> PUNCT ::::: .
# A ----> DET ::::: a
# baseball ----> NOUN ::::: baseball
# rolls ----> VERB ::::: roll
# up ----> ADP ::::: up
# to ----> ADP ::::: to
# Buster ----> PROPN ::::: Buster
# ’s ----> PART ::::: ’s
# feet ----> NOUN ::::: foot
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Harry ----> PROPN ::::: Harry
# Mills ----> PROPN ::::: Mills
# : ----> PUNCT ::::: :
# Wow ----> INTJ ::::: wow
# ! ----> PUNCT ::::: !
# You ----> PRON ::::: you
# 're ----> AUX ::::: be
# even ----> ADV ::::: even
# slower ----> ADJ ::::: slow
# than ----> ADP ::::: than
# Ebos ----> PROPN ::::: Ebos
# Shmecter ----> PROPN ::::: Shmecter
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# Hi ----> PROPN ::::: Hi
# , ----> PUNCT ::::: ,
# Harry ----> PROPN ::::: Harry
# . ----> PUNCT ::::: .
# What ----> PRON ::::: what
# are ----> AUX ::::: be
# you ----> PRON ::::: you
# doing ----> VERB ::::: do
# here ----> ADV ::::: here
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# Harry ----> PROPN ::::: Harry
# Mills ----> PROPN ::::: Mills
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# was ----> AUX ::::: be
# just ----> ADV ::::: just
# on ----> ADP ::::: on
# my ----> PRON ::::: my
# way ----> NOUN ::::: way
# to ----> PART ::::: to
# get ----> VERB ::::: get
# a ----> DET ::::: a
# milkshake ----> NOUN ::::: milkshake
# with ----> ADP ::::: with
# your ----> PRON ::::: your
# mother ----> NOUN ::::: mother
# , ----> PUNCT ::::: ,
# and ----> CCONJ ::::: and
# I ----> PRON ::::: I
# thought ----> VERB ::::: think
# you ----> PRON ::::: you
# might ----> AUX ::::: might
# like ----> VERB ::::: like
# to ----> PART ::::: to
# join ----> VERB ::::: join
# us ----> PRON ::::: we
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# 're ----> AUX ::::: be
# getting ----> VERB ::::: get
# a ----> DET ::::: a
# milkshake ----> NOUN ::::: milkshake
# with ----> ADP ::::: with
# her ----> PRON ::::: she
# ? ----> PUNCT ::::: ?
# You ----> PRON ::::: you
# mean ----> VERB ::::: mean
# it ----> PRON ::::: it
# worked ----> VERB ::::: work
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# Harry ----> PROPN ::::: Harry
# Mills ----> PROPN ::::: Mills
# : ----> PUNCT ::::: :
# Um ----> INTJ ::::: um
# , ----> PUNCT ::::: ,
# no ----> INTJ ::::: no
# , ----> PUNCT ::::: ,
# we ----> PRON ::::: we
# ’re ----> AUX ::::: ’re
# still ----> ADV ::::: still
# broken ----> VERB ::::: break
# up ----> ADP ::::: up
# . ----> PUNCT ::::: .
# But ----> CCONJ ::::: but
# we ----> PRON ::::: we
# ’re ----> VERB ::::: ’re
# also ----> ADV ::::: also
# still ----> ADV ::::: still
# friends ----> NOUN ::::: friend
# , ----> PUNCT ::::: ,
# just ----> ADV ::::: just
# like ----> ADP ::::: like
# you ----> PRON ::::: you
# and ----> CCONJ ::::: and
# me ----> PRON ::::: I
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# So ----> ADV ::::: so
# , ----> PUNCT ::::: ,
# can ----> AUX ::::: can
# we ----> PRON ::::: we
# still ----> ADV ::::: still
# go ----> VERB ::::: go
# to ----> ADP ::::: to
# Grebes ----> PROPN ::::: Grebes
# games ----> NOUN ::::: game
# together ----> ADV ::::: together
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# Harry ----> PROPN ::::: Harry
# Mills ----> PROPN ::::: Mills
# : ----> PUNCT ::::: :
# Sure ----> INTJ ::::: sure
# . ----> PUNCT ::::: .
# In ----> ADP ::::: in
# fact ----> NOUN ::::: fact
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# have ----> VERB ::::: have
# a ----> DET ::::: a
# little ----> ADJ ::::: little
# project ----> NOUN ::::: project
# I ----> PRON ::::: I
# was ----> AUX ::::: be
# wondering ----> VERB ::::: wonder
# if ----> SCONJ ::::: if
# you ----> PRON ::::: you
# could ----> AUX ::::: could
# help ----> VERB ::::: help
# me ----> PRON ::::: I
# with ----> ADP ::::: with
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# * ----> PUNCT ::::: *
# * ----> PUNCT ::::: *
# * ----> PUNCT ::::: *
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# , ----> PUNCT ::::: ,
# Bitzi ----> PROPN ::::: Bitzi
# and ----> CCONJ ::::: and
# Harry ----> PROPN ::::: Harry
# sit ----> VERB ::::: sit
# in ----> ADP ::::: in
# the ----> DET ::::: the
# Sugar ----> PROPN ::::: Sugar
# Bowl ----> PROPN ::::: Bowl
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# Go ----> VERB ::::: go
# ahead ----> ADV ::::: ahead
# , ----> PUNCT ::::: ,
# Mom ----> PROPN ::::: Mom
# . ----> PUNCT ::::: .
# She ----> PRON ::::: she
# bites ----> VERB ::::: bite
# into ----> ADP ::::: into
# a ----> DET ::::: a
# sandwich ----> NOUN ::::: sandwich
# . ----> PUNCT ::::: .
# Well ----> INTJ ::::: well
# , ----> PUNCT ::::: ,
# what ----> PRON ::::: what
# do ----> AUX ::::: do
# you ----> PRON ::::: you
# think ----> VERB ::::: think
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# Mrs. ----> PROPN ::::: Mrs.
# Baxter ----> PROPN ::::: Baxter
# : ----> PUNCT ::::: :
# Who ----> PRON ::::: who
# would ----> AUX ::::: would
# have ----> AUX ::::: have
# ever ----> ADV ::::: ever
# thought ----> VERB ::::: think
# that ----> SCONJ ::::: that
# salami ----> NOUN ::::: salami
# , ----> PUNCT ::::: ,
# Swiss ----> ADJ ::::: swiss
# cheese ----> NOUN ::::: cheese
# and ----> CCONJ ::::: and
# peanut ----> NOUN ::::: peanut
# butter ----> NOUN ::::: butter
# could ----> AUX ::::: could
# be ----> AUX ::::: be
# so ----> ADV ::::: so
# ... ----> PUNCT ::::: ...
# delicious ----> ADJ ::::: delicious
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# Do ----> AUX ::::: do
# you ----> PRON ::::: you
# think ----> VERB ::::: think
# there ----> PRON ::::: there
# should ----> AUX ::::: should
# be ----> AUX ::::: be
# more ----> ADJ ::::: more
# mayo ----> NOUN ::::: mayo
# on ----> ADP ::::: on
# it ----> PRON ::::: it
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# Mrs. ----> PROPN ::::: Mrs.
# Baxter ----> PROPN ::::: Baxter
# : ----> PUNCT ::::: :
# Oh ----> INTJ ::::: oh
# , ----> PUNCT ::::: ,
# no ----> INTJ ::::: no
# ! ----> PUNCT ::::: !
# There ----> PRON ::::: there
# 's ----> VERB ::::: be
# plenty ----> NOUN ::::: plenty
# of ----> ADP ::::: of
# mayo ----> NOUN ::::: mayo
# on ----> ADP ::::: on
# it ----> PRON ::::: it
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# Mm ----> PROPN ::::: Mm
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# guess ----> VERB ::::: guess
# it ----> PRON ::::: it
# 's ----> AUX ::::: be
# an ----> DET ::::: an
# acquired ----> VERB ::::: acquire
# taste ----> NOUN ::::: taste
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Harry ----> PROPN ::::: Harry
# Mills ----> PROPN ::::: Mills
# : ----> PUNCT ::::: :
# Well ----> INTJ ::::: well
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# 've ----> AUX ::::: have
# acquired ----> VERB ::::: acquire
# it ----> PRON ::::: it
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Mrs. ----> PROPN ::::: Mrs.
# Baxter ----> PROPN ::::: Baxter
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# two ----> NUM ::::: two
# better ----> ADJ ::::: well
# hurry ----> NOUN ::::: hurry
# . ----> PUNCT ::::: .
# The ----> DET ::::: the
# game ----> NOUN ::::: game
# starts ----> VERB ::::: start
# in ----> ADP ::::: in
# five ----> NUM ::::: five
# minutes ----> NOUN ::::: minute
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Buster ----> PROPN ::::: Buster
# : ----> PUNCT ::::: :
# It ----> PRON ::::: it
# 's ----> AUX ::::: be
# okay ----> ADJ ::::: okay
# if ----> SCONJ ::::: if
# we ----> PRON ::::: we
# 're ----> AUX ::::: be
# a ----> DET ::::: a
# little ----> ADJ ::::: little
# late ----> ADJ ::::: late
# . ----> PUNCT ::::: .
# The ----> DET ::::: the
# Grebes ----> PROPN ::::: Grebes
# usually ----> ADV ::::: usually
# only ----> ADV ::::: only
# give ----> VERB ::::: give
# up ----> ADP ::::: up
# two ----> NUM ::::: two
# runs ----> NOUN ::::: run
# in ----> ADP ::::: in
# the ----> DET ::::: the
# first ----> ADJ ::::: first
# inning ----> NOUN ::::: inning
# . ----> PUNCT ::::: .
# See ----> VERB ::::: see
# you ----> PRON ::::: you
# , ----> PUNCT ::::: ,
# Mom ----> PROPN ::::: Mom
# ! ----> PUNCT ::::: !
#
#
#  ----> SPACE :::::
#
#
# He ----> PRON ::::: he
# leaves ----> VERB ::::: leave
# with ----> ADP ::::: with
# Harry ----> PROPN ::::: Harry
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Mrs. ----> PROPN ::::: Mrs.
# Baxter ----> PROPN ::::: Baxter
# : ----> PUNCT ::::: :
# Can ----> AUX ::::: can
# I ----> PRON ::::: I
# get ----> VERB ::::: get
# this ----> DET ::::: this
# " ----> PUNCT ::::: "
# Buster ----> PROPN ::::: Buster
# " ----> PUNCT ::::: "
# to ----> PART ::::: to
# go ----> VERB ::::: go
# , ----> PUNCT ::::: ,
# please ----> INTJ ::::: please
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# The ----> DET ::::: the
# waitress ----> NOUN ::::: waitress
# takes ----> VERB ::::: take
# her ----> PRON ::::: her
# sandwich ----> NOUN ::::: sandwich
# . ----> PUNCT ::::: .
# The ----> DET ::::: the
# menu ----> NOUN ::::: menu
# now ----> ADV ::::: now
# has ----> VERB ::::: have
# a ----> DET ::::: a
# new ----> ADJ ::::: new
# offering ----> NOUN ::::: offering
# called ----> VERB ::::: call
# “ ----> PUNCT ::::: "
# The ----> DET ::::: the
# Buster ----> PROPN ::::: Buster
# ” ----> PUNCT ::::: "
# . ----> PUNCT ::::: .
